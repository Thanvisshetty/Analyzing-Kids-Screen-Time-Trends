# %% [markdown]
# ## **EXPLORATORY DATA ANALYSIS**

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/kids_screen_time_dataset (2).csv')
## fecth the first 5 rows
df.head(5)
# Out:
#    Child_ID    Name  Age  Gender    Country  \
# 0         1   Kavya   12  Female  Australia
# 1         2  Vivaan   10    Male  Australia
# 2         3   Kunal   12    Male        USA
# 3         4   Meera    7  Female      India
# 4         5   Priya   17  Female     Canada
#
#    Average_Screen_Time_per_Day_Hours Device_Used       Purpose  \
# 0                                6.4      Tablet     Education
# 1                                0.7      Laptop  Social Media
# 2                                7.5      Tablet  Social Media
# 3                                7.7      Mobile  Social Media
# 4                                2.6          TV        Gaming
#
#   Parental_Control  Sleep_Hours  Physical_Activity_Hours EffectOnKid
# 0              Yes          6.3                      0.9         Yes
# 1               No          5.5                      2.3         Yes
# 2               No          6.5                      2.8         Yes
# ...

# %%
df = df.drop('Child_ID', axis=1)
display(df.head())
# Out:
#      Name  Age  Gender    Country  Average_Screen_Time_per_Day_Hours  \
# 0   Kavya   12  Female  Australia                                6.4
# 1  Vivaan   10    Male  Australia                                0.7
# 2   Kunal   12    Male        USA                                7.5
# 3   Meera    7  Female      India                                7.7
# 4   Priya   17  Female     Canada                                2.6
#
#   Device_Used       Purpose Parental_Control  Sleep_Hours  \
# 0      Tablet     Education              Yes          6.3
# 1      Laptop  Social Media               No          5.5
# 2      Tablet  Social Media               No          6.5
# 3      Mobile  Social Media              Yes          8.6
# 4          TV        Gaming               No          5.5
#
#    Physical_Activity_Hours EffectOnKid
# 0                      0.9         Yes
# 1                      2.3         Yes
# 2                      2.8         Yes
# ...

# %%
df.tail(5)
# Out:
#           Name  Age  Gender    Country  Average_Screen_Time_per_Day_Hours  \
# 99995   Shreya    6  Female      India                                2.6
# 99996    Kavya   11  Female  Australia                                4.5
# 99997  Reyansh    5    Male  Australia                                4.6
# 99998    Aarav   10    Male         UK                                6.4
# 99999     Tara   12  Female  Australia                                2.7
#
#       Device_Used        Purpose Parental_Control  Sleep_Hours  \
# 99995      Mobile   Social Media              Yes          6.2
# 99996      Mobile  Entertainment               No          9.7
# 99997          TV  Entertainment              Yes         10.0
# 99998      Mobile  Entertainment              Yes          9.8
# 99999      Mobile      Education               No          8.2
#
#        Physical_Activity_Hours EffectOnKid
# 99995                      2.0         Yes
# 99996                      2.1         Yes
# ...

# %%
df.describe()
# Out:
#                  Age  Average_Screen_Time_per_Day_Hours    Sleep_Hours  \
# count  100000.000000                      100000.000000  100000.000000
# mean       10.994980                           4.242249       7.497674
# std         3.748194                           2.165175       1.445841
# min         5.000000                           0.500000       5.000000
# 25%         8.000000                           2.400000       6.200000
# 50%        11.000000                           4.200000       7.500000
# 75%        14.000000                           6.100000       8.700000
# max        17.000000                           8.000000      10.000000
#
#        Physical_Activity_Hours
# count            100000.000000
# mean                  1.505145
# std                   0.866941
# min                   0.000000
# 25%                   0.800000
# 50%                   1.500000
# 75%                   2.300000
# max                   3.000000

# %%
df.dtypes
# Out:
# Name                                  object
# Age                                    int64
# Gender                                object
# Country                               object
# Average_Screen_Time_per_Day_Hours    float64
# Device_Used                           object
# Purpose                               object
# Parental_Control                      object
# Sleep_Hours                          float64
# Physical_Activity_Hours              float64
# EffectOnKid                           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Name                                 0
# Age                                  0
# Gender                               0
# Country                              0
# Average_Screen_Time_per_Day_Hours    0
# Device_Used                          0
# Purpose                              0
# Parental_Control                     0
# Sleep_Hours                          0
# Physical_Activity_Hours              0
# EffectOnKid                          0
# dtype: int64

# %%
## Handling Missing Values
df.isnull().any()
# Out:
# Name                                 False
# Age                                  False
# Gender                               False
# Country                              False
# Average_Screen_Time_per_Day_Hours    False
# Device_Used                          False
# Purpose                              False
# Parental_Control                     False
# Sleep_Hours                          False
# Physical_Activity_Hours              False
# EffectOnKid                          False
# dtype: bool

# %%
df_filled=df.fillna(0)

# %%
## Renaming Columns
df=df.rename(columns={'Average_Screen_Time_per_Day_Hours':'Average Screen Time'})
df.head()
# Out:
#      Name  Age  Gender    Country  Average Screen Time Device_Used  \
# 0   Kavya   12  Female  Australia                  6.4      Tablet
# 1  Vivaan   10    Male  Australia                  0.7      Laptop
# 2   Kunal   12    Male        USA                  7.5      Tablet
# 3   Meera    7  Female      India                  7.7      Mobile
# 4   Priya   17  Female     Canada                  2.6          TV
#
#         Purpose Parental_Control  Sleep_Hours  Physical_Activity_Hours  \
# 0     Education              Yes          6.3                      0.9
# 1  Social Media               No          5.5                      2.3
# 2  Social Media               No          6.5                      2.8
# 3  Social Media              Yes          8.6                      0.8
# 4        Gaming               No          5.5                      2.9
#
#   EffectOnKid
# 0         Yes
# 1         Yes
# 2         Yes
# 3         Yes
# 4         Yes

# %%
grouped_mean=df.groupby('Purpose')['Average Screen Time'].mean()
print(grouped_mean)
# Out:
# Purpose
# Education        4.220585
# Entertainment    4.247099
# Gaming           4.259981
# Social Media     4.241382
# Name: Average Screen Time, dtype: float64

# %%
# Create sample DataFrames
df1 = pd.DataFrame({'Key': ['A', 'B', 'C'], 'Value1': [1, 2, 3]})
df2 = pd.DataFrame({'Key': ['A', 'B', 'D'], 'Value2': [4, 5, 6]})

# %%
df1
# Out:
#   Key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   Key  Value2
# 0   A       4
# 1   B       5
# 2   D       6

# %%
import seaborn as sns

# %%
### Basic Plotting With Seaborn
df=pd.read_csv('/content/kids_screen_time_dataset (2).csv')
df=df.rename(columns={'Average_Screen_Time_per_Day_Hours':'Average Screen Time'})

# %%
sns.lineplot(x='Age',y='Average Screen Time',data=df)
plt.title("Line Plot of Average Screen Time by Age")
plt.show()

# %%
## Categorical Plots
## BAr Plot
sns.barplot(x='EffectOnKid',y='Sleep_Hours',data=df)
plt.title('Bar Plot of Effect on Kid By Gender')
plt.show()

# %%
## Box Plot
sns.boxplot(x="Purpose",y='Sleep_Hours',data=df)
plt.title('Box Plot of Sleep Hours by Purpose')
plt.show()
